# %%
# Extraer la columna de workclass
inputs = np.array(df)
workclass= inputs[:,1]
#print(workclass)
# Create label encoder and fit the labels
encoder1 = preprocessing.LabelEncoder()
encoder1.fit(workclass)
# Print the mapping 
print("\Workclass nLabel mapping:")
for i, item in enumerate(encoder1.classes_):
    print(item, '-->', i)

# Encode a set of labels using the encoder
encoded_values1 = encoder1.transform(workclass)
print("\nLabels =", workclass)
#print("Encoded values =", list(encoded_values7))
df['workclass'] = encoded_values1
################################################################################

# Extraer la columna de education

education= inputs[:,3]
#print(education)
# Create label encoder and fit the labels
encoder2 = preprocessing.LabelEncoder()
encoder2.fit(education)
# Print the mapping 
print("\nEducation Label mapping:")
for i, item in enumerate(encoder.classes_):
    print(item, '-->', i)

# Encode a set of labels using the encoder
encoded_values2 = encoder2.transform(education)
#print("\nLabels =", workclass)
#print("Encoded values =", list(encoded_values7))
df['education'] = encoded_values2

###################################################################

# Extraer la columna de marital-status

mS= inputs[:,5]
#print(mS)
# Create label encoder and fit the labels
encoder3 = preprocessing.LabelEncoder()
encoder3.fit(mS)
# Print the mapping 
print("\nmarital-status Label mapping:")
for i, item in enumerate(encoder.classes_):
    print(item, '-->', i)

# Encode a set of labels using the encoder
encoded_values3 = encoder3.transform(mS)
#print("\nLabels =", workclass)
#print("Encoded values =", list(encoded_values7))
df['marital-status'] = encoded_values3

###################################################################

# Extraer la columna de occupation

occupation= inputs[:,6]
#print(occupation)
# Create label encoder and fit the labels
encoder4 = preprocessing.LabelEncoder()
encoder4.fit(occupation)
# Print the mapping 
print("\noccupation Label mapping:")
for i, item in enumerate(encoder.classes_):
    print(item, '-->', i)

# Encode a set of labels using the encoder
encoded_values4 = encoder4.transform(occupation)
#print("\nLabels =", workclass)
#print("Encoded values =", list(encoded_values7))
df['occupation'] = encoded_values4

###################################################################


# Extraer la columna de native-country
inputs = np.array(df)
nativecountry= inputs[:,13]
#print(nativecountry)
# Create label encoder and fit the labels
encoder5 = preprocessing.LabelEncoder()
encoder5.fit(nativecountry)
# Print the mapping 
print("\nNative Country mapping:")
for i, item in enumerate(encoder5.classes_):
    print(item, '-->', i)

# Encode a set of labels using the encoder
encoded_values7 = encoder5.transform(nativecountry)
#print("\nLabels =", workclass)
#print("Encoded values =", list(encoded_values7))
df['native-country'] = encoded_values7
#df.head()
